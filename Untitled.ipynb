# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('STATUS ASIGNACIÓN INDRA_GENERAL (HANSSEL)_2022.csv', encoding='latin-1')
df
# Out:
#            MES                SITE  \
# 0        ENERO             POLO II
# 1        ENERO  CEMENTOS PACASMAYO
# 2        ENERO            CULEBRAS
# 3        ENERO    DOCUMENTACIÓN PL
# 4        ENERO   INSPECCIÓN TORRES
# ..         ...                 ...
# 300  DICIEMBRE               PICSI
# 301  DICIEMBRE         VILLA MARÍA
# 302  DICIEMBRE       SANTA LUCÍA 2
# 303  DICIEMBRE      LAS CASUARINAS
# 304  DICIEMBRE     LA VICTORIA URA
#
#                                            DESCRIPCIÓN DEPARTAMENTO  \
# 0    CAMBIO PISO TÉCNICO - SALAS DATA CENTER TI, MS...         LIMA
# 1                INSPECCIÓN DE ESTADO DE TORRE VENTADA     TRUJILLO
# 2                      CAMBIO DE TORRE VENTADA H = 18M       ÁNCASH
# 3           INGRESO DE DOCUMENTACIÓN EN MESA DE PARTES         LIMA
# 4    INSPECCIÓN + EVALUACIÓN ESTRUCTURAL + MANTENIM...       VARIOS
# ..                                                 ...          ...
# 300                         1. CAMBIO DE CHAPA SIMPLE.         LIMA
# 301                         1. CAMBIO DE CHAPA SIMPLE.         LIMA
# 302  1. CAMBIO DE CHAPA SIMPLE (2 UND).\n2. INSTALA...         LIMA
# 303                         1. CAMBIO DE CHAPA SIMPLE.         LIMA
# 304  1. COLOCACIÓN DE LÁMINA PLÁSTICA (TAPIADO DE V...         LIMA
#
#     GESTOR DE TRABAJO FECHA SOLICITUD STATUS COTIZACIÓN FECHA COTIZACION  \
# 0           GOYTIZOLO           3-Jan           ENVIADA           12-Jan
# 1              VARGAS           7-Jan         PENDIENTE        PENDIENTE
# 2              VARGAS           7-Jan           ENVIADA           17-Jan
# 3              VARGAS          12-Jan         PENDIENTE        PENDIENTE
# 4              VARGAS          12-Jan           ENVIADA           15-Feb
# ..                ...             ...               ...              ...
# 300            ORTEGA          19-Dec           ENVIADA           19-Dec
# 301          MARTÍNEZ          19-Dec           ENVIADA           19-Dec
# 302          MARTÍNEZ          19-Dec           ENVIADA           19-Dec
# 303          MARTÍNEZ          19-Dec           ENVIADA           19-Dec
# 304          MARTÍNEZ          19-Dec           ENVIADA           19-Dec
#
#     STATUS APROBACION FECHA APROBACION STATUS EJECUCIÓN FECHA INFORME  \
# 0           PENDIENTE        PENDIENTE    SIN EJECUCIÓN           NaN
# 1           PENDIENTE        PENDIENTE    SIN EJECUCIÓN           NaN
# 2           PENDIENTE        PENDIENTE    SIN EJECUCIÓN           NaN
# 3           PENDIENTE        PENDIENTE     EN EJECUCIÓN        20-Jan
# 4           PENDIENTE        PENDIENTE    SIN EJECUCIÓN           NaN
# ..                ...              ...              ...           ...
# 300          APROBADA           20-Dec    SIN EJECUCIÓN           NaN
# 301          APROBADA           20-Dec    SIN EJECUCIÓN           NaN
# 302          APROBADA           20-Dec    SIN EJECUCIÓN           NaN
# 303          APROBADA           20-Dec    SIN EJECUCIÓN           NaN
# 304          APROBADA           20-Dec    SIN EJECUCIÓN           NaN
#
#     FECHA DE INICIO EJECUCION FECHA DE FIN EJECUCION MONTO COTIZADO
# 0                         NaN                    NaN      281434.94
# 1                         NaN                    NaN        1194.94
# 2                         NaN                    NaN       18888.52
# 3                      18-Jan                 20-Jan           -
# 4                         NaN                    NaN          70000
# ..                        ...                    ...            ...
# 300                       NaN                    NaN            420
# 301                       NaN                    NaN            280
# 302                       NaN                    NaN            620
# 303                       NaN                    NaN            280
# 304                       NaN                    NaN            400
#
# [305 rows x 15 columns]

# %%
df.describe()
# Out:
#            MES         SITE             DESCRIPCIÓN DEPARTAMENTO  \
# count      305          305                     305          305
# unique      12          230                     245           24
# top     AGOSTO  CHIMBOTE CT  CAMBIO DE CHAPA SIMPLE         LIMA
# freq        46            9                      19          127
#
#        GESTOR DE TRABAJO FECHA SOLICITUD STATUS COTIZACIÓN FECHA COTIZACION  \
# count                305             305               305              305
# unique                16             116                 4              114
# top               VARGAS          24-Jun           ENVIADA        CANCELADO
# freq                 119              13               245               27
#
#        STATUS APROBACION FECHA APROBACION STATUS EJECUCIÓN FECHA INFORME  \
# count                305              305              305            95
# unique                 3               61                4            59
# top            PENDIENTE        PENDIENTE    SIN EJECUCIÓN        30-Sep
# freq                 169              169              176             5
#
#        FECHA DE INICIO EJECUCION FECHA DE FIN EJECUCION MONTO COTIZADO
# count                         97                     97            305
# unique                        76                     74            210
# top                       15-Nov                 22-Nov           -
# freq                           4                      4             30

# %%
df['MONTO COTIZADO'] = pd.to_numeric(df['MONTO COTIZADO'], errors='coerce')
df = df.replace(np.nan, 0, regex=True)

# %%
df.loc[(df['STATUS APROBACION'] == 'APROBADA'), ['MONTO COTIZADO']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 5 to 304
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MONTO COTIZADO  104 non-null    float64
# dtypes: float64(1)
# memory usage: 1.6 KB

# %%
df.loc[(df['STATUS APROBACION'] == 'APROBADA'), ['MONTO COTIZADO']].sum()
# Out:
# MONTO COTIZADO    345384.72
# dtype: float64

# %%
plt.bar('MES', df['SITE'].value_counts)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [150], in <cell line: 1>()
# ----> 1 plt.bar('MES', df['SITE'].value_counts)
#       2 plt.show()
#
# File ~\anaconda3\envs\Sample\lib\site-packages\matplotlib\pyplot.py:2399, in bar(x, height, width, bottom, align, data, **kwargs)
#    2395 @_copy_docstring_and_deprecators(Axes.bar)
#    2396 def bar(
#    2397         x, height, width=0.8, bottom=None, *, align='center',
#    2398         data=None, **kwargs):
# -> 2399     return gca().bar(
#    2400         x, height, width=width, bottom=bottom, align=align,
#    2401         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\envs\Sample\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\envs\Sample\lib\site-packages\matplotlib\axes\_axes.py:2395, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2392 args = zip(left, bottom, width, height, color, edgecolor, linewidth,
#    2393            hatch)
#    2394 for l, b, w, h, c, e, lw, htch in args:
# -> 2395     r = mpatches.Rectangle(
#    2396         xy=(l, b), width=w, height=h,
#    2397         facecolor=c,
#    2398         edgecolor=e,
#    2399         linewidth=lw,
#    2400         label='_nolegend_',
#    2401         hatch=htch,
#    2402         )
#    2403     r.update(kwargs)
#    2404     r.get_path()._interpolation_steps = 100
#
# File ~\anaconda3\envs\Sample\lib\site-packages\matplotlib\patches.py:739, in Rectangle.__init__(self, xy, width, height, angle, **kwargs)
#     737 self._height = height
#     738 self.angle = float(angle)
# --> 739 self._convert_units()
#
# File ~\anaconda3\envs\Sample\lib\site-packages\matplotlib\patches.py:750, in Rectangle._convert_units(self)
#     748 y0 = self.convert_yunits(self._y0)
#     749 x1 = self.convert_xunits(self._x0 + self._width)
# --> 750 y1 = self.convert_yunits(self._y0 + self._height)
#     751 return x0, y0, x1, y1
#
# TypeError: unsupported operand type(s) for +: 'int' and 'method'

# %%
approved = df['STATUS APROBACION'] == 'APROBADA'
df['GESTOR DE TRABAJO'].value_counts()
# Out:
# VARGAS                     119
# MARTÍNEZ                    57
# VARGAS/URBINA ARIBA         44
# ARIBA                       30
# ISTEY                       13
# ORTEGA                      11
# CHIPANA/URBINA ARIBA         8
# GOYTIZOLO                    5
# MARTÍNEZ/KAPUSTÍN ARIBA      5
# KAPUSTÍN                     4
# CHIPANA                      4
# PORTELLA                     1
# ISTEY - KAPUSTÍN             1
# MARTÍNEZ/URBINA ARIBA        1
# SIERRA/KAPUSTÍN ARIBA        1
# ORTEGA/KAPUSTÍN ARIBA        1
# Name: GESTOR DE TRABAJO, dtype: int64

# %%
approved = df['STATUS APROBACION'] == 'APROBADA'
df[approved]['GESTOR DE TRABAJO'].value_counts()
# Out:
# VARGAS                   38
# MARTÍNEZ                 31
# VARGAS/URBINA ARIBA      14
# ISTEY                     7
# CHIPANA                   4
# ORTEGA                    3
# GOYTIZOLO                 2
# ARIBA                     2
# PORTELLA                  1
# CHIPANA/URBINA ARIBA      1
# ORTEGA/KAPUSTÍN ARIBA     1
# Name: GESTOR DE TRABAJO, dtype: int64

# %%
df.loc[(df['STATUS APROBACION'] == 'APROBADA') & (df['GESTOR DE TRABAJO'] == 'VARGAS'), ['MES', 'MONTO COTIZADO']].sum().to_frame()
# Out:
#                                                                 0
# MES             ENEROENEROFEBREROMARZOMARZOABRILABRILABRILABRI...
# MONTO COTIZADO                                          184969.03

# %%
df.loc[(df['STATUS APROBACION'] == 'APROBADA'), 'MONTO COTIZADO'].groupby(df['MES'])
